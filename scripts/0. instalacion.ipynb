# %%
# ------------------------------------------------------------
# INSTALACIÓN Y CARGA DE LIBRERÍAS
# ------------------------------------------------------------
# Lista de paquetes necesarios
paquetes <- c('tidyverse', 'janitor', 'lubridate', 'scales',
              'ggrepel', 'knitr', 'kableExtra')

# Instalación automática si no están presentes

install.packages(paquetes)

library(tidyverse)
library(janitor)
library(lubridate)
library(scales)
library(ggplot2)

# ------------------------------------------------------------
# 2) CARGA DE DATASETS
# ------------------------------------------------------------
data_path <- "/content"  # Ajustar según ubicación de archivos

campaigns_raw    <- read_csv(file.path(data_path, "campaigns.csv"), show_col_types = FALSE) %>% clean_names()
customers_raw    <- read_csv(file.path(data_path, "customers.csv"), show_col_types = FALSE) %>% clean_names()
products_raw     <- read_csv(file.path(data_path, "products.csv"), show_col_types = FALSE) %>% clean_names()
events_raw       <- read_csv(file.path(data_path, "events.csv"), show_col_types = FALSE) %>% clean_names()
transactions_raw <- read_csv(file.path(data_path, "transactions.csv"), show_col_types = FALSE) %>% clean_names()
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
